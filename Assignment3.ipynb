# %% [markdown]
# <a href="https://colab.research.google.com/github/rishitdass/assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Question 1

# %%
dict={"Refund":["Yes","No","No","Yes","No","No","Yes","No","No","No"],
      "Marital Status":["Single","Married","Single","Married","Divorced","Married","Divorced","Single","Married","Single"],
      "Taxable Income":["125K","100K","70K","120K","95K","60K","220K","85K","75K","90K"],
      "Cheat":["No","No","No","No","No","Yes","No","No","Yes","Yes"]}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#   Refund Marital Status Taxable Income Cheat
# 0    Yes         Single           125K    No
# 1     No        Married           100K    No
# 2     No         Single            70K    No
# 3    Yes        Married           120K    No
# 4     No       Divorced            95K    No
# 5     No        Married            60K   Yes
# 6    Yes       Divorced           220K    No
# 7     No         Single            85K    No
# 8     No        Married            75K   Yes
# 9     No         Single            90K   Yes

# %% [markdown]
# #Question 2

# %%
df.loc[4]
# Out:
# Refund                  No
# Marital Status    Divorced
# Taxable Income         95K
# Cheat                   No
# Name: 4, dtype: object

# %%
df.loc[0]
# Out:
# Refund               Yes
# Marital Status    Single
# Taxable Income      125K
# Cheat                 No
# Name: 0, dtype: object

# %%
df.loc[7],df.loc[8]
# Out:
# (Refund                No
#  Marital Status    Single
#  Taxable Income       85K
#  Cheat                 No
#  Name: 7, dtype: object,
#  Refund                 No
#  Marital Status    Married
#  Taxable Income        75K
#  Cheat                 Yes
#  Name: 8, dtype: object)

# %% [markdown]
# #Question 2

# %%
data2=pd.read_csv("/content/Airplane_Crashes_and_Fatalities_Since_1908.csv")

# %%
data2.head(10)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
# 5  03/05/1915  01:00                     Tienen, Belgium
# 6  09/03/1915  15:20               Off Cuxhaven, Germany
# 7  07/28/1916    NaN               Near Jambol, Bulgeria
# 8  09/24/1916  01:00                 Billericay, England
# 9  10/01/1916  23:45                Potters Bar, England
#
#                  Operator Flight #          Route  \
# 0    Military - U.S. Army      NaN  Demonstration
# 1    Military - U.S. Navy      NaN    Test flight
# 2                 Private        -            NaN
# 3  Military - German Navy      NaN            NaN
# 4  Military - German Navy      NaN            NaN
# ...
